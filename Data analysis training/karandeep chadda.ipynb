# %% [markdown]
# # __DATA ANALYSIS USING PYTHON__
#
#  ___SUBMITED BY:-___
#  ___KARANDEEP CHADDA___

# %% [markdown]
# # __GIVEN DATASET:-__

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Dataset.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # ___CLEANING THE GIVEN DATASET___

# %%
# I HAVE ALREADY CLEANED IT SO DONT RUN IT AGAIN!!!!!!!

# the given data set has non alphabetical-characters.we have to replace them!

import pandas as pd
import unicodedata

# Load the dataset
df = pd.read_csv('Dataset.csv')

# Removing cells Missing Values
df.dropna(inplace=True)

# Removing Duplicates
df.drop_duplicates(inplace=True)

# Function to replace non-ASCII characters with ASCII equivalents
def replace_non_ascii(text):
    return ''.join(char if ord(char) < 128 else unicodedata.normalize('NFKD', char).encode('ascii', 'ignore').decode('utf-8', 'ignore') for char in str(text))

# Replace non-ASCII characters in all columns
df = df.map(replace_non_ascii)

# Reset index after modifying DataFrame
df.reset_index(drop=True, inplace=True)

# (I HAVE SAVED IT ALREADY! THATS WHY I HAVE COMMENTED THE BELOW CODE!)

# df.to_csv('cleaned_dataset.csv', index=False)

# %% [markdown]
# __****************************************************************************************************************************************************************__

# %% [markdown]
# # __LEVEL 1__

# %% [markdown]
# ## ___TASK 1 : TOP CUISINES___

# %% [markdown]
#  * ### _TASK 1.1_
#
# "Determine the top three most common cuisines in the dataset"

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')  
cuisine_counts = df['Cuisines'].value_counts()

# Sort the cuisines by frequency
sorted_cuisines = cuisine_counts.sort_values(ascending=False)

top_three_cuisines = sorted_cuisines.head(3)
print("Top three most common cuisines in Given DATASET are:\n\n\t{}".format(top_three_cuisines))
# Out:
# Top three most common cuisines in Given DATASET are:
#
# 	Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %% [markdown]
# ==========================================================================================================

# %% [markdown]
# * ### _TASK 1.2_
#
# "Calculate the percentage of restaurants that serve each of the top cuisines"

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')  
total_restaurants = len(df)

# Sort the cuisines by frequency
sorted_cuisines = cuisine_counts.sort_values(ascending=False)

top_three_cuisines = sorted_cuisines.head(3)
print("Percentage of restaurants serving each of the top cuisines form the given Dataset is :-")
for cuisines, count in top_three_cuisines.items():
    percentage = (count / total_restaurants) * 100
    print(f"\n{cuisines} :- {percentage:.3f}% ")
# Out:
# Percentage of restaurants serving each of the top cuisines form the given Dataset is :-
#
# North Indian :- 9.809%
#
# North Indian, Chinese :- 5.355%
#
# Chinese :- 3.710%

# %% [markdown]
# __***************************************************************************************************************************************************************__

# %% [markdown]
# # ___TASK 2 : CITY ANALYSIS___

# %% [markdown]
# * ### _TASK 2.1_
#
# "Identify the city with the highest number of restaurants in the dataset."

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')  
city_counts = df['City'].value_counts()

# Identify the city with the highest number of restaurants
city_with_highest_restaurants = city_counts.idxmax()

print(f"The city with the highest number of restaurants is :- {city_with_highest_restaurants}")
# Out:
# The city with the highest number of restaurants is :- New Delhi

# %% [markdown]
# ===========================================================================================================

# %% [markdown]
# * ### _TASK 2.2_
# "Calculate the average rating for restaurants in each city"

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')  
average_rating_by_city = df.groupby('City')['Aggregate rating'].median().sort_values(ascending=False)

# changing default pandas display settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print("Average rating for restaurants in each city From given dataset :-\n \n\t{}\n".format (average_rating_by_city))
# Out:
# Average rating for restaurants in each city From given dataset :-
#
# 	City
# Inner City                4.90
# Quezon City               4.80
# Pasig City                4.80
# Makati City               4.65
# Mandaluyong City          4.60
# Beechworth                4.60
# Rio de Janeiro            4.55
# London                    4.55
# Taguig City               4.50
# Tagaytay City             4.50
# Secunderabad              4.50
# Lincoln                   4.50
# Tampa Bay                 4.45
# Bangalore                 4.40
# Tanunda                   4.40
# Dubai                     4.40
# Rest of Hawaii            4.40
# Orlando                   4.40
# Palm Cove                 4.40
# Auckland                  4.35
# Jakarta                   4.35
# Tangerang                 4.30
# Mohali                    4.30
# Clatskanie                4.30
# Chennai                   4.30
# Abu Dhabi                 4.30
# Vernonia                  4.30
# ...

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# * ### _TASK 2.3_
#
# "Determine the city with the highest average rating"

# %%
average_rating_by_city = df.groupby('City')['Aggregate rating'].mean()

# Find the city with the highest average rating
city_with_highest_average_rating = average_rating_by_city.idxmax()
highest_average_rating = average_rating_by_city.max()

print(f"The city with the highest average rating is: {city_with_highest_average_rating}, with an Average Of: {highest_average_rating}!")
# Out:
# The city with the highest average rating is: Inner City, with an Average Of: 4.9!

# %% [markdown]
# __******************************************************************************************************************************************************************__

# %% [markdown]
# # ___TASK 3: Price Range Distribution___

# %% [markdown]
# * ### _TASK 3.1_
#
# "Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants"

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('cleaned_dataset.csv')
price_range_counts = df['Price range'].value_counts().sort_index()
# Plotting the bar chart
plt.figure(figsize=(4,3))
price_range_counts.plot(kind='bar', color='purple', edgecolor='yellow')
plt.xlabel('Price Range')
plt.ylabel('Restaurants within Price Range')
plt.title('Distribution of Price Ranges Among Restaurants')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ==========================================================================================================

# %% [markdown]
# * ### _TASK 3.2_
#
# "Calculate the percentage of restaurants in each price range category"

# %%
import pandas as pd
df = pd.read_csv('cleaned_dataset.csv')
price_range_counts = df['Price range'].value_counts()

total_restaurants = price_range_counts.sum()

percentage_per_price_range = (price_range_counts / total_restaurants) * 100
percentage_per_price_range = percentage_per_price_range.round(2)

print("Percentage of restaurants in each Price Range :\n\n{}".format(percentage_per_price_range))
# Out:
# Percentage of restaurants in each Price Range :
#
# Price range
# 1    46.51
# 2    32.62
# 3    14.72
# 4     6.14
# Name: count, dtype: float64

# %% [markdown]
# __**************************************************************************************************************************************************************__

# %% [markdown]
# # ___TASK  4: Online Delivery___

# %% [markdown]
# * ### ___TASK 4.1___
# "Determine the percentage of restaurants that offer online delivery"

# %%
online_delivery_counts = df['Has Online delivery'].value_counts()

total_restaurants = df.shape[0]

percentage_online_delivery = (online_delivery_counts['Yes'] / total_restaurants) * 100

print(f"Percentage of restaurants that offers online delivery is:- {percentage_online_delivery:.2f} %")
# Out:
# Percentage of restaurants that offers online delivery is:- 25.69 %

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# * ### ___TASK 4.2___
# "Compare the average ratings of restaurants with and without online delivery."

# %%
average_rating_by_delivery = df.groupby('Has Online delivery')['Aggregate rating'].mean()
average_rating_by_delivery = average_rating_by_delivery.round(2)
print("The average ratings of restaurants with and without online delivery is :-\n\n{}".format(average_rating_by_delivery))
# Out:
# The average ratings of restaurants with and without online delivery is :-
#
# Has Online delivery
# No     2.46
# Yes    3.25
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# ____******************************************************************                (END OF LEVEL 1)     **********************************************************************____

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# # __LEVEL 2__

# %% [markdown]
# # ___TASK 1: Restaurant Ratings___

# %% [markdown]
# * ### ___TASK 1.1___
# "Analyze the distribution of aggregate ratings and determine the most common rating range"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')

# Count the frequency of each rating range
rating_range_counts = df['Aggregate rating'].value_counts().sort_index()

# Plotting the bar chart
plt.figure(figsize=(10, 5))
rating_range_counts.plot(kind='bar', color='purple', edgecolor='yellow')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Aggregate Ratings Among Restaurants')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
mode_rating = df['Aggregate rating'].mode()

print("The most common rating range is:",mode_rating)
# Out:
# The most common rating range is: 0    0.0
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# ============================================================================================================

# %% [markdown]
# * ### ___TASK 1.2___
# "Calculate the average number of votes received by restaurants"

# %%
Average_Votes=df['Votes'].mean()
Average_Votes=Average_Votes.__round__(2)
print("Average number of votes recived by Resturants are : {}".format(Average_Votes),"Votes")
# Out:
# Average number of votes recived by Resturants are : 156.77 Votes

# %% [markdown]
# __*****************************************************************************************************************************************************************__

# %% [markdown]
# # ___TASK 2: Cuisine Combination___

# %% [markdown]
# * ### ___TASK 2.1___
# "Identify the most common combinations of cuisines in the dataset"

# %%
import pandas as pd
df=pd.read_csv('cleaned_dataset.csv')
# Split the 'Cuisines' column into lists of cuisines
df['Cuisines'] = df['Cuisines'].str.split(', ')
# Count the occurrences of each combination of cuisines
cuisine_combinations = df['Cuisines'].apply(frozenset).value_counts()
print("Most common combinations of cuisines in the dataset:\n\n\t{}".format(cuisine_combinations.head(10)))
print("\n..........................................................")
print("\nTOP #3 MOST COMMON COMBINATION OF CUISINES IS :\n\n\t{}".format(cuisine_combinations.head(3)))
# Out:
# Most common combinations of cuisines in the dataset:
#
# 	Cuisines
# (North Indian)                      936
# (North Indian, Chinese)             616
# (Mughlai, North Indian)             395
# (Fast Food)                         354
# (Chinese)                           354
# (Mughlai, North Indian, Chinese)    306
# (Cafe)                              299
# (Bakery)                            218
# (Desserts, Bakery)                  182
# (Chinese, Fast Food)                159
# Name: count, dtype: int64
#
# ..........................................................
#
# TOP #3 MOST COMMON COMBINATION OF CUISINES IS :
#
# 	Cuisines
# (North Indian)             936
# (North Indian, Chinese)    616
# (Mughlai, North Indian)    395
# Name: count, dtype: int64

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# * ### ___TASK 2.2___
# "Determine if certain cuisine combinations tend to have higher ratings."

# %%
import pandas as pd

df=pd.read_csv('cleaned_dataset.csv')

# combine cuisines into a single column
df['Combined Cuisines'] = df['Cuisines'].str.split(', ').apply(frozenset)

# calculate the average rating for each combination of cuisines
average_rating_by_cuisine_combination = df.groupby('Combined Cuisines')['Aggregate rating'].mean()

# printing results
print("Average ratings for each combination of cuisines:\n\n\t{}".format(average_rating_by_cuisine_combination.head(15)))
print("\n............................................................................................................................................")
print("\nFROM THE DATA ABOVE WE CAN SEE THAT COMBINATION OF",list(average_rating_by_cuisine_combination.index[0]),"RESULTS IN HIGHER AVG RATING OF :"  ,average_rating_by_cuisine_combination.iloc[0])
# Out:
# Average ratings for each combination of cuisines:
#
# 	Combined Cuisines
# (Desserts, Japanese, French)                                    4.800000
# (Nepalese)                                                      1.333333
# (North Indian, Continental, European, Italian, Asian, Pizza)    4.100000
# (Thai, Continental, Chinese)                                    3.650000
# (American, Finger Food, Mexican)                                4.200000
# (British, Chinese, Italian)                                     3.800000
# (Italian, American, Fast Food)                                  3.650000
# (American, Burger, Fast Food, Italian, Pizza)                   4.500000
# (Healthy Food, Chinese)                                         2.800000
# (Mughlai, Chinese, Kashmiri)                                    3.300000
# (European, Sushi, Italian)                                      3.000000
# (Fast Food, Ice Cream, Beverages)                               1.675000
# ...

# %% [markdown]
# __*************************************************************************************************************************************************************__

# %% [markdown]
# # ___TASK 3: Geographic Analysis___

# %% [markdown]
# * ### ___TASK 3.1___
# "Plot the locations of restaurants on a map using longitude and latitude coordinates"

# %%
import pandas as pd
import folium

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')

# Create a map centered at Nagpur,INDIA 
map_restaurants = folium.Map(location=[21.0859,79.0450], zoom_start=10)

# Add markers for each restaurant
for index, row in df.iterrows():
     folium.Marker([row['Latitude'], row['Longitude']], popup=row['Restaurant Name']).add_to(map_restaurants)

# saving map  as HTML
map_restaurants.save('Task 3.1 map.html')

#  DUE TO VERY LARGE NUMBER OF MARKER POINTS IN THE DATASET I HAVE CENTERED THE MAP @ NAGPUR, WE CAN SCOLL TO SEE ALL THE MARKERS ON THE WORLD MAP BUT THE PAGE MIGHT GET UN-RESPONSIVE DUE TO THE LARGE SET OF DATA.

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# * ### ___TASK 3.2___
# "Identify any patterns or clusters of restaurants in specific areas"

# %%
import pandas as pd
import folium
from folium.plugins import FastMarkerCluster

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')

# Create a map centered at INDIA 
map_restaurants = folium.Map(location=[28.3650,77.1232], zoom_start=5)
Latitude = df['Latitude']
Longitude = df['Longitude']

FastMarkerCluster(data=list(zip(Latitude,Longitude))).add_to(map_restaurants)

# saving map as HTML
map_restaurants.save('Task 3.2 cluster map.html')

# %% [markdown]
# __*************************************************************************************************************************************************************__

# %% [markdown]
# # ___TASK 4: Restaurant Chains___

# %% [markdown]
# * ### ___TASK 4.1___
# "Identify if there are any restaurant chains present in the dataset"

# %%
import pandas as pd

df = pd.read_csv('cleaned_dataset.csv')

restaurant_names = df['Restaurant Name'].str.lower()

# a dictionary to store potential restaurant chains
restaurant_chains = {}

# Iterate over each restaurant name
for name in restaurant_names:
    for chain_name in restaurant_chains.keys():
        if chain_name in name:
            restaurant_chains[chain_name].append(name)
            break
    else:
        restaurant_chains[name] = [name]

potential_chains = [(chain_name, restaurants) for chain_name, restaurants in restaurant_chains.items() if len(restaurants) > 1]

# Print potential restaurant chains

print("Potential restaurant chains are:-")
print()
for chain_name, restaurants in potential_chains:
    print(f"Chain: {chain_name.capitalize()}")
    for restaurant in restaurants:
        print(f"-{restaurant.title()}")
    print("....................")
    print()
# Out:
# Potential restaurant chains are:-
#
# Chain: Din tai fung
# -Din Tai Fung
# -Din Tai Fung
# ....................
#
# Chain: Vikings
# -Vikings
# -Niu By Vikings
# ....................
#
# Chain: Silantro fil-mex
# -Silantro Fil-Mex
# -Silantro Fil-Mex
# ....................
#
# Chain: Coco bambu
# -Coco Bambu
# -Coco Bambu
# ....................
#
# Chain: Bibi
# -Bibi
# -Habibi Express
# -Habibi
# -Habibi Express
# -Habibi
# -Habibi Express
# ....................
#
# Chain: Garota de ipanema
# -Garota De Ipanema
# -Garota De Ipanema
# ....................
#
# Chain: Chick-fil-a
# -Chick-Fil-A
# -Chick-Fil-A
# ....................
#
# Chain: The grill
# -The Grill
# -The Grillz & Gravy
# -The Grill Darbar
# -The Grill Mill
# -The Grills King
# -The Grill Kitchen - Gourmet
# -The Grill Point
# -The Grill Kitchen
# -The Grill Cafe
# -The Grill Room - The Lalit New Delhi
# -The Grill Room - The Taj Mahal Hotel
# -The Grill @ 76
# -The Grill On The Alley
# ....................
#
# ...

# %% [markdown]
# ==========================================================================================================

# %% [markdown]
# * ### ___TASK 4.2___
# "Analyze the ratings and popularity of different restaurant chains"

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('cleaned_dataset.csv')

# Aggregate data by restaurant chains
chain_stats = df.groupby('Restaurant Name').agg({'Aggregate rating': 'mean', 'Votes': 'sum', 'City': 'count'})

# Rename columns for clarity
chain_stats.rename(columns={'Aggregate rating': 'Average Rating', 'Votes':  'Total Votes', 'City':  'Total Restaurants'}, inplace=True)

# Sort by total votes in descending order
chain_stats = chain_stats.sort_values(by='Total Votes', ascending=False)

# Print the summary statistics for the top 10 restaurant chains
print("Summary for the top 10 Restaurant chains:\n")
print(chain_stats.head(10))
# Out:
# Summary for the top 10 Restaurant chains:
#
#                            Average Rating  Total Votes  Total Restaurants
# Restaurant Name
# Barbeque Nation                  4.353846        28142                 26
# AB's - Absolute Barbecues        4.825000        13400                  4
# Toit                             4.800000        10934                  1
# Big Chill                        4.475000        10853                  4
# Farzi Cafe                       4.366667        10098                  6
# Truffles                         3.950000         9682                  2
# Chili's                          4.580000         8156                  5
# Hauz Khas Social                 4.300000         7931                  1
# Joey's Pizza                     4.250000         7807                  2
# Peter Cat                        4.300000         7574                  1

# %% [markdown]
# ==========================================================================================================
#
# _***************************************************************************             ___(END OF TASKS)___              ********************************************************************************_
#
# ==========================================================================================================
